# %% [markdown]
# # Credit Card Retention Analysis

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import plotly.graph_objs as go
from plotly.offline import iplot
sns.set()
pd.options.display.max_columns = 999

# %%
data = pd.read_csv('../data/BankChurners_v2.csv')

# %%
data = data[['CLIENTNUM', 'Attrition_Flag', 'Customer_Age', 'Gender',
       'Dependent_count', 'Education_Level', 'Marital_Status',
       'Income_Category', 'Card_Category', 'Months_on_book',
       'Total_Relationship_Count', 'Months_Inactive_12_mon',
       'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
       'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
       'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio',]]

# %%
data['Education_Level'] = data['Education_Level'].fillna('Unknown')
data['Marital_Status'] = data['Marital_Status'].fillna('Unknown')
data['Income_Category'] = data['Income_Category'].fillna('Unknown')

# %% [markdown]
# ***

# %% [markdown]
# ## Data Transformation: Binning

# %% [markdown]
# To bin our ages, we will need a couple data points: the min and max ages. Let's find those.

# %%
print(data['Customer_Age'].min())
print(data['Customer_Age'].max())
# Out:
# 26
# 73

# %% [markdown]
# For more information, see the documentation [here](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.cut.html).

# %%
bins= [25,30,40,50,60,70,80]
labels= ['20s','30s','40s','50s','60s','70s']
data['Customer_Age_bins']= pd.cut(data['Customer_Age'],bins=bins, labels= labels, include_lowest=True,right=False)

# %%
data[data["Customer_Age"]==40]
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 3          90035  Existing Customer            40      F                4
# 4          90036  Existing Customer            40      M                3
# 150        90182  Existing Customer            40      M                3
# 259        90291  Existing Customer            40      M                1
# 271        90303  Existing Customer            40      M                2
# ...          ...                ...           ...    ...              ...
# 9996      100028  Attrited Customer            40      F                4
# 10018     100050  Attrited Customer            40      F                2
# 10056     100088  Existing Customer            40      F                3
# 10078     100110  Existing Customer            40      M                3
# 10092     100124  Attrited Customer            40      F                3
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# 3         High School        Unknown  Less than $40K          Blue
# 4          Uneducated        Married     $60K - $80K          Blue
# 150       High School         Single    $80K - $120K          Blue
# 259          Graduate        Married     $40K - $60K          Blue
# 271        Uneducated       Divorced     $60K - $80K          Blue
# ...               ...            ...             ...           ...
# 9996       Uneducated       Divorced  Less than $40K          Blue
# 10018        Graduate         Single  Less than $40K          Blue
# 10056      Uneducated         Single  Less than $40K          Blue
# 10078     High School       Divorced     $60K - $80K          Blue
# 10092        Graduate        Married         Unknown          Blue
#
#        Months_on_book  Total_Relationship_Count  Months_Inactive_12_mon  \
# 3                  34                         3                       4
# 4                  21                         5                       1
# 150                28                         5                       1
# 259                23                         6                       3
# 271                29                         5                       3
# ...               ...                       ...                     ...
# 9996               35                         2                       3
# 10018              30                         5                       3
# 10056              33                         4                       3
# 10078              36                         3                       1
# 10092              25                         1                       2
#
#        Contacts_Count_12_mon  Credit_Limit  Total_Revolving_Bal  \
# 3                          1        3313.0                 2517
# 4                          0        4716.0                    0
# 150                        0       21617.0                    0
# 259                        2        6990.0                 1378
# 271                        0       23603.0                    0
# ...                      ...           ...                  ...
# 9996                       3        4423.0                 2517
# 10018                      6        4458.0                    0
# 10056                      2        3804.0                 1917
# 10078                      2       16268.0                 2517
# 10092                      3        6888.0                 1878
#
#        Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  Total_Trans_Ct  \
# 3                796.0                 1.405             1171              20
# 4               4716.0                 2.175              816              28
# 150            21617.0                 1.047             1351              22
# 259             5612.0                 0.730             1479              29
# 271            23603.0                 0.795             1382              31
# ...                ...                   ...              ...             ...
# 9996            1906.0                 0.840             8935              87
# 10018           4458.0                 0.935             9640              70
# 10056           1887.0                 0.744            14321             102
# 10078          13751.0                 0.652            15925             124
# 10092           5010.0                 1.059             9038              64
#
#        Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio Customer_Age_bins
# 3                    2.333                  0.760               40s
# 4                    2.500                  0.000               40s
# 150                  0.467                  0.000               40s
# 259                  0.611                  0.197               40s
# 271                  1.067                  0.000               40s
# ...                    ...                    ...               ...
# 9996                 0.933                  0.569               40s
# 10018                0.707                  0.000               40s
# 10056                0.759                  0.504               40s
# 10078                0.824                  0.155               40s
# 10092                0.829                  0.273               40s
#
# [361 rows x 22 columns]
